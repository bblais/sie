# %% [markdown]
# ## MCMC part of the libary

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(timeit)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L50){target="_blank" style="float:right; font-size:smaller"}
#
# ### timeit
#
# >      timeit (reset=False)

# %%
#| echo: false
#| output: asis
show_doc(time2str)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### time2str
#
# >      time2str (tm)

# %%
#| echo: false
#| output: asis
show_doc(histogram)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### histogram
#
# >      histogram (y, bins=50, plot=True)

# %% [markdown]
# ## Distribution Log Likelihoods

# %%
#| echo: false
#| output: asis
show_doc(init_Jeffreys)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L307){target="_blank" style="float:right; font-size:smaller"}
#
# ### init_Jeffreys
#
# >      init_Jeffreys (sum=False)

# %%
#| echo: false
#| output: asis
show_doc(Jeffreys)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L294){target="_blank" style="float:right; font-size:smaller"}
#
# ### Jeffreys
#
# >      Jeffreys ()

# %%
#| echo: false
#| output: asis
show_doc(init_HalfNormal)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L279){target="_blank" style="float:right; font-size:smaller"}
#
# ### init_HalfNormal
#
# >      init_HalfNormal (μ, σ, sum=False)

# %%
#| echo: false
#| output: asis
show_doc(HalfNormal)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L258){target="_blank" style="float:right; font-size:smaller"}
#
# ### HalfNormal
#
# >      HalfNormal (μ, σ, sum=False)

# %%
#| echo: false
#| output: asis
show_doc(init_StudentT)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L243){target="_blank" style="float:right; font-size:smaller"}
#
# ### init_StudentT
#
# >      init_StudentT (μ, σ, sum=False)

# %%
#| echo: false
#| output: asis
show_doc(StudentT)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L217){target="_blank" style="float:right; font-size:smaller"}
#
# ### StudentT
#
# >      StudentT (df, mu, sd, sum=False)

# %%
#| echo: false
#| output: asis
show_doc(init_Exponential)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L201){target="_blank" style="float:right; font-size:smaller"}
#
# ### init_Exponential
#
# >      init_Exponential (scale, offset=0, sum=False)

# %%
#| echo: false
#| output: asis
show_doc(Exponential)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L169){target="_blank" style="float:right; font-size:smaller"}
#
# ### Exponential
#
# >      Exponential (scale, offset=0, sum=False)

# %%
#| echo: false
#| output: asis
show_doc(init_Uniform)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L154){target="_blank" style="float:right; font-size:smaller"}
#
# ### init_Uniform
#
# >      init_Uniform (mn, mx, sum=False)

# %%
#| echo: false
#| output: asis
show_doc(Uniform)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L124){target="_blank" style="float:right; font-size:smaller"}
#
# ### Uniform
#
# >      Uniform (mn, mx, sum=False)

# %%
#| echo: false
#| output: asis
show_doc(init_Normal)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L110){target="_blank" style="float:right; font-size:smaller"}
#
# ### init_Normal
#
# >      init_Normal (μ, σ, sum=True)

# %%
#| echo: false
#| output: asis
show_doc(Normal)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L93){target="_blank" style="float:right; font-size:smaller"}
#
# ### Normal
#
# >      Normal (μ, σ, sum=True)

# %% [markdown]
# ## Main MCMC Definitions

# %%
#| echo: false
#| output: asis
show_doc(StatsModel)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L351){target="_blank" style="float:right; font-size:smaller"}
#
# ### StatsModel
#
# >      StatsModel ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Parameter)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L318){target="_blank" style="float:right; font-size:smaller"}
#
# ### Parameter
#
# >      Parameter (eqn, initial_value=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(StatsModel.make_func)
# Out:
# ---
#
# [source](https://github.com/bblais/sie/blob/main/sie/mcmc.py#L679){target="_blank" style="float:right; font-size:smaller"}
#
# ### StatsModel.make_func
#
# >      StatsModel.make_func ()
